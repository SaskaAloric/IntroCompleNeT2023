# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Text

# %% [markdown]
# \begin{equation}
# 1+\frac{1}{2}+\frac{1}{3}+\ldots
# \end{equation}

# %% [markdown]
# # How to move a cell?

# %% [markdown]
# Mark the cell you want move and use arrows to move them.

# %% [markdown]
# Text can have a variety

# %% [markdown]
# **Text**

# %% [markdown]
# *Text*

# %% [markdown]
# Line <br> break

# %% [markdown]
# Mathematical symbols

# %% [markdown]
# $ \alpha $, $\beta$, $\gamma$

# %% [markdown]
# Colors

# %% [markdown]
# <font color=blue>Blues</font> <br>
# <font color=red>Red</font> <br>
# <font color=green>Green</font>

# %% [markdown]
# Indented quoting

# %% [markdown]
# > Text

# %% [markdown]
# Bullets

# %% [markdown]
# - List 1
#     - List 1.1
# - List 2

# %% [markdown]
# #### Graphics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     Horizontal line

# %% [markdown]
# ***

# %% [markdown]
# Internal links

# %% [markdown]
# <a id="section1"></a>

# %% [markdown]
# [A link to section 1](#section1)

# %% [markdown]
# External link

# %% [markdown]
# [Markdown for Jupyter notebooks cheatsheet](https://ingeh.medium.com/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed)
